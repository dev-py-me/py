# %%
# !apt-get update
# !apt-get upgrade
# !apt-get install make git zlib1g-dev libssl-dev gperf cmake g++

# %%
# !git clone --recursive https://github.com/tdlib/telegram-bot-api.git
# %cd telegram-bot-api

# %%
# !rm -rf build
# !mkdir build
# %cd build
# !cmake -DCMAKE_BUILD_TYPE=Debug -DCMAKE_INSTALL_PREFIX:PATH=.. ..
# !cmake --build . --target install
# %cd ../..
# !ls -l telegram-bot-api/bin/telegram-bot-api*

# %%
# %cd /content/
# Out:
# /content

# %%
#!git clone https://github.com/RtiM0/telegram-download-bot.git
# !git clone https://github.com/dev-py-me/telegram-download-bot.git
# %cd telegram-download-bot
# !python -m pip install -r requirements.txt

# %%
# !sudo mkdir /content/mega
# !nohup rclone mount mega: /content/mega &

# %%
# %cd /content/telegram-bot-api/bin/
# !./telegram-bot-api --api-id 7712824 --api-hash 2d3673e18b462f8032c4eea2f50b9f52 --local

# %%
# %cd /content/telegram-download-bot/telegram-download-bot/
# !python3 bot.py

# %%
# %cd /content/telegram-download-bot/
# !python3 bot.py

# %%
import os
import threading

def conda():
  # %cd /content/telegram-bot-api/bin/
  # !./telegram-bot-api --api-id 7712824 --api-hash 2d3673e18b462f8032c4eea2f50b9f52 --local

def wget():
  # %cd /content/telegram-download-bot/
  # !python3 bot.py

# creating thread
t1 = threading.Thread(target=conda, args=())
t2 = threading.Thread(target=wget, args=())

# starting thread 1
t1.start()
# starting thread 2
t2.start()
# startling thread

# wait until thread 1 is completely executed
t1.join()
# wait until thread 2 is completely executed
t2.join()
# wait until thread 2 is completely executed


# both threads completely executed
print("Done!")
# Out:
# /content/telegram-bot-api/bin
# /content/telegram-download-bot
# 2024-01-07 20:05:57,269 - apscheduler.scheduler - INFO - Scheduler started
# 2024-01-07 20:05:57,270 - telegram.ext._application - INFO - Application started
# ...

# %%
# !rm -rf /content/mega/*.MP4
